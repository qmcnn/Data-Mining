# %% [markdown]
# <a href="https://colab.research.google.com/github/qmcnn/Data-Mining/blob/main/Data_Preprocessing_(Chapter_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # ทำงานกับข้อมูลลักษณะ ตาราง
import numpy as np

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # จัดการไฟล์และ path

# %%
path = '/content/drive/MyDrive/Year4/Data Mining/confirmed-cases.csv'

# %%
data_cases = pd.read_csv(path)
data_cases
# Out:
# <ipython-input-5-accd03c6d8b6>:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_cases = pd.read_csv(path)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# ...

# %%
data_cases.loc[data_cases['announce_date']=='26/7/2021'].index
# Out:
# Int64Index([497302, 497303, 497304, 497305, 497306, 497307, 497308, 497309,
#             497310, 497311,
#             ...
#             512668, 512669, 512670, 512671, 512672, 512673, 512674, 512675,
#             512676, 512677],
#            dtype='int64', length=15376)

# %% [markdown]
# # ชี้ข้อมูลในตาราง

# %%
data_cases['risk']
# Out:
# 0         คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         คนต่างชาติเดินทางมาจากต่างประเทศ
#                         ...
# 839766                    ทัณฑสถาน/เรือนจำ
# 839767                    ทัณฑสถาน/เรือนจำ
# 839768                    ทัณฑสถาน/เรือนจำ
# 839769                    ทัณฑสถาน/เรือนจำ
# 839770                    ทัณฑสถาน/เรือนจำ
# Name: risk, Length: 839771, dtype: object

# %%
data_cases[['risk','age']]
# Out:
#                                     risk   age
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ  61.0
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ  74.0
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ  73.0
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ  68.0
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ  66.0
# ...                                  ...   ...
# 839766                  ทัณฑสถาน/เรือนจำ  52.0
# 839767                  ทัณฑสถาน/เรือนจำ  34.0
# 839768                  ทัณฑสถาน/เรือนจำ  31.0
# 839769                  ทัณฑสถาน/เรือนจำ  83.0
# 839770                  ทัณฑสถาน/เรือนจำ  47.0
#
# [839771 rows x 2 columns]

# %%
data_cases['risk'][666]
# Out:
# 'สนามมวย'

# %% [markdown]
# # ชี้โดยใช้ .iloc[] (แปลงมุมมองให้เป็น matrix)

# %%
data_cases.iloc[4,4]
# Out:
# 66.0

# %%
data_cases.iloc[-50:,:]
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 839721  839722     12/8/2021     11/8/2021   ชาย  19.0   ปี    Thailand
# 839722  839723     12/8/2021     11/8/2021  หญิง  60.0   ปี    Thailand
# 839723  839724     12/8/2021     11/8/2021  หญิง  49.0   ปี    Thailand
# 839724  839725     12/8/2021     11/8/2021  หญิง  51.0   ปี    Thailand
# 839725  839726     12/8/2021     11/8/2021  หญิง  36.0   ปี    Thailand
# 839726  839727     12/8/2021     11/8/2021  หญิง  44.0   ปี    Thailand
# 839727  839728     12/8/2021     11/8/2021  หญิง  34.0   ปี    Thailand
# 839728  839729     12/8/2021     11/8/2021  หญิง  59.0   ปี    Thailand
# 839729  839730     12/8/2021     11/8/2021  หญิง  53.0   ปี    Thailand
# 839730  839731     12/8/2021     11/8/2021  หญิง  40.0   ปี    Thailand
# 839731  839732     12/8/2021     11/8/2021  หญิง  35.0   ปี    Thailand
# 839732  839733     12/8/2021     11/8/2021  หญิง  26.0   ปี    Thailand
# ...

# %%
data_cases.loc[(data_cases['province_of_isolation']== 'ขอนแก่น') & (data_cases['province_of_onset']== 'ขอนแก่น'),:]
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี    Thailand
# 463        464     22/3/2020     21/3/2020  หญิง  36.0   ปี    Thailand
# 1467      1468     30/3/2020     26/3/2020   ชาย  19.0   ปี    Thailand
# 1971      1972      3/4/2020     31/3/2020  หญิง  70.0   ปี    Thailand
# 2638      2639     15/4/2020     14/4/2020  หญิง  63.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839669  839670     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 839670  839671     12/8/2021     11/8/2021   ชาย  58.0   ปี    Thailand
# 839671  839672     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839672  839673     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
# 839673  839674     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# ...

# %%
data_cases.loc[data_cases["nationality"] == 'Thailand']
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 15          16     31/1/2020           NaN   ชาย  50.0   ปี    Thailand
# 19          20      4/2/2020           NaN  หญิง  43.0   ปี    Thailand
# 20          21      4/2/2020           NaN   ชาย  49.0   ปี    Thailand
# 22          23      4/2/2020           NaN   ชาย  45.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839759  839760     12/8/2021     11/8/2021   ชาย  33.0   ปี    Thailand
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation  \
# 2                     นครปฐม
# 15             กรุงเทพมหานคร
# ...

# %%
data_cases["nationality"]=="ลาว"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 839766    False
# 839767    False
# 839768    False
# 839769    False
# 839770    False
# Name: nationality, Length: 839771, dtype: bool

# %%
data_cases[data_cases["nationality"]=="lao"] = "laos"

# %%
data_cases.iloc[-50:,[3,6,8]]
# Out:
#          sex nationality              risk
# 839721   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839722  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839723  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839724  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839725  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839726  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839727  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839728  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839729  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839730  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839731  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839732  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839733  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 839734  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839735  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839736  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839737  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839738  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 839739  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839740  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839741  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# ...

# %% [markdown]
# # Descriptive Statistics of Data

# %%
data_cases.describe()
# Out:
#            No. announce_date Notified date     sex       age    Unit  \
# count   839771        839771        836976  784876  763606.0  763746
# unique  839771           523           498       3     238.0       5
# top          1     12/8/2021     11/8/2021    หญิง      25.0      ปี
# freq         1         22782         22782  399881   19058.0  761170
#
#        nationality province_of_isolation  \
# count       755567                839499
# unique         245                    77
# top       Thailand         กรุงเทพมหานคร
# freq        651511                226349
#
#                                                risk province_of_onset  \
# count                                        838677            740737
# unique                                          128               180
# top     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# freq                                         303184            200233
#
#        district_of_onset
# count             680992
# ...

# %% [markdown]
# # Missing Value
#
#
#
# *   Null
# *   NaN = Not a Number
# *   NA = Not available

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
data_cases.isnull()
# Out:
#           No.  announce_date  Notified date    sex    age   Unit  nationality  \
# 0       False          False           True  False  False  False        False
# 1       False          False           True  False  False  False        False
# 2       False          False           True  False  False  False        False
# 3       False          False           True  False  False  False        False
# 4       False          False           True  False  False  False        False
# ...       ...            ...            ...    ...    ...    ...          ...
# 839766  False          False          False  False  False  False         True
# 839767  False          False          False  False  False  False        False
# 839768  False          False          False  False  False  False        False
# 839769  False          False          False  False  False  False        False
# 839770  False          False          False  False  False  False        False
#
# ...

# %%
data_cases.isnull().any()  # .any() คือ Or ในแนว columns
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases.isnull().any().any()
# Out:
# True

# %%
data_cases.isnull().all()  # .all() คือ and ในแนว columns
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# # Handling Missing Value 1 (ลบค่า missing )

# %%
data_cases.shape
# Out:
# (839771, 11)

# %%
data_cases_M1 = data_cases.dropna()
data_cases_M1
# Out:
#            No. announce_date Notified date   sex   age Unit     nationality  \
# 47          48      6/3/2020      4/3/2020   ชาย  43.0   ปี  United Kingdom
# 124        125      6/3/2021      5/3/2021  หญิง  55.0   ปี        Thailand
# 161        162     17/3/2020     21/3/2020   ชาย  14.0   ปี        Thailand
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี        Thailand
# 186        187     18/3/2020     16/3/2020   ชาย  36.0   ปี        Thailand
# ...        ...           ...           ...   ...   ...  ...             ...
# 839391  839392     12/8/2021     11/8/2021  หญิง  83.0   ปี        Thailand
# 839392  839393     12/8/2021     11/8/2021   ชาย  66.0   ปี        Thailand
# 839393  839394     12/8/2021     11/8/2021  หญิง  43.0   ปี        Thailand
# 839394  839395     12/8/2021     11/8/2021  หญิง  74.0   ปี        Thailand
# 839395  839396     12/8/2021     11/8/2021   ชาย  29.0   ปี        Thailand
#
#        province_of_isolation  \
# ...

# %%
data_cases_M1.shape
# Out:
# (599988, 11)

# %% [markdown]
# size before drop = 1000
#
# size after drop = 10
#
# we lost 99% of data

# %%
print('size before drop = ',len(data_cases))
print('size after drop = ', len(data_cases_M1))
print('we lost ', ((len(data_cases)-len(data_cases_M1))/len(data_cases))*100, '% of data')
# Out:
# size before drop =  839771
# size after drop =  599988
# we lost  28.553379433202625 % of data

# %%
print(f'size before drop = {len(data_cases)}')
print('size after drop = ', len(data_cases_M1))
print(f'we lost {((len(data_cases)-len(data_cases_M1))/len(data_cases))*100:.2f}% of data')
# Out:
# size before drop = 839771
# size after drop =  599988
# we lost 28.55% of data

# %% [markdown]
# ## Handling Missing Value 1.5 (ลบค่า missing เฉพาะใน column ที่เราสนใจ)

# %%
data_cases_M15 = data_cases.dropna(subset=['Notified date', 'sex', 'age'])

# %%
data_cases_M15.shape
# Out:
# (733511, 11)

# %% [markdown]
# HW
#
# ```print``` ของ missing 1.5
#
# size before drop = 1000
#
# size after drop = 10
#
# we lost 99% of data
#
# now we have x% more data than handling_missing1

# %% [markdown]
# ## Handling Missing Value 2 แทนด้วยค่าที่เหมาะสมหรือสร้าง class ใหม่

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
data_cases['age'] = data_cases['age'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-9915f89acf4e> in <cell line: 1>()
# ----> 1 data_cases['age'] = data_cases['age'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
[i for i in data_cases['age'] if i=='55/664']
# Out:
# ['55/664']

# %%
data_cases['age'][data_cases['age']=='55/664'] = np.nan

# %%
[i for i in data_cases['age'] if i=='55/664']
# Out:
# []

# %%
data_cases['age'] = data_cases['age'].astype(float)

# %%
data_cases['age'].describe()
# Out:
# count    763605.000000
# mean         35.700109
# std          16.597799
# min           0.750000
# 25%          24.000000
# 50%          34.000000
# 75%          46.000000
# max         440.000000
# Name: age, dtype: float64

# %%
data_cases['age'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 839766    False
# 839767    False
# 839768    False
# 839769    False
# 839770    False
# Name: age, Length: 839771, dtype: bool

# %%
data_cases['age'].isna().sum()
# Out:
# 76166

# %%
data_cases['age'].mean() ## ถ้า function ไม่ได้ป้องกัน data ที่มี missing ไว้
# Out:
# 35.70010851159959

# %%
data_cases[['Notified date']] = data_cases[['Notified date']].fillna('99/99/9999')

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ### ดู column unit

# %%
data_cases['Unit']
# Out:
# 0         ปี
# 1         ปี
# 2         ปี
# 3         ปี
# 4         ปี
#           ..
# 839766    ปี
# 839767    ปี
# 839768    ปี
# 839769    ปี
# 839770    ปี
# Name: Unit, Length: 839771, dtype: object

# %%
set(data_cases['Unit']) ## หา unique values
# Out:
# {' วัน', ' เดือน', nan, 'ปี', 'วัน', 'เดือน'}

# %%
(data_cases['Unit']=='วัน').sum()
# Out:
# 139

# %% [markdown]
# ## [PD] วิธีเลือก record โดยการกำหนดค่า

# %%
data_cases[data_cases['Unit']=='วัน']
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 19706    19707      2/2/2021      1/2/2021  หญิง  26.0  วัน       Burma
# 23791    23792     10/2/2021      9/2/2021  หญิง   2.0  วัน       Burma
# 40961    40962     18/4/2021     17/4/2021  หญิง   3.0  วัน    Thailand
# 57745    57746     27/4/2021     26/4/2021  หญิง  10.0  วัน    Thailand
# 65454    65455      1/5/2021     30/4/2021   ชาย   7.0  วัน    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 786915  786916     10/8/2021      9/8/2021  หญิง   8.0  วัน         NaN
# 787832  787833     10/8/2021      9/8/2021   ชาย  27.0  วัน    Thailand
# 789523  789524     10/8/2021      9/8/2021   ชาย  28.0  วัน    Thailand
# 816034  816035     11/8/2021     10/8/2021   ชาย   1.0  วัน    Thailand
# 817116  817117     12/8/2021     11/8/2021   ชาย  27.0  วัน    Thailand
#
#        province_of_isolation                                         risk  \
# ...

# %%
data_cases[data_cases['Unit']==' วัน']
# Out:
#            No. announce_date Notified date  sex   age  Unit nationality  \
# 138777  138778     27/5/2021     26/5/2021  ชาย  23.0   วัน     Burmese
#
#        province_of_isolation                                         risk  \
# 138777           สมุทรปราการ  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#        province_of_onset district_of_onset
# 138777       สมุทรปราการ            บางพลี

# %% [markdown]
# ```python
# data_frame[list_of_logics] #list_of_logics มีขนาดเท่ากับจำนวน record ของ data_frame
# ```

# %%
data_cases['Unit']=='วัน'  # list_of_logics
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 839766    False
# 839767    False
# 839768    False
# 839769    False
# 839770    False
# Name: Unit, Length: 839771, dtype: bool

# %%
data_cases[data_cases['Unit']=='วัน'].sort_values(by='age')
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 770185  770186      9/8/2021      8/8/2021  หญิง   1.0  วัน    Thailand
# 771397  771398      9/8/2021      8/8/2021  หญิง   1.0  วัน    Thailand
# 611316  611317      1/8/2021     31/7/2021   ชาย   1.0  วัน    Thailand
# 597624  597625      1/8/2021     31/7/2021   ชาย   1.0  วัน     Burmese
# 565946  565947     30/7/2021     29/7/2021  หญิง   1.0  วัน     Burmese
# ...        ...           ...           ...   ...   ...  ...         ...
# 291193  291194      6/7/2021      5/7/2021  หญิง  28.0  วัน    Thailand
# 789523  789524     10/8/2021      9/8/2021   ชาย  28.0  วัน    Thailand
# 530438  530439     28/7/2021     27/7/2021  หญิง  29.0  วัน    Thailand
# 443530  443531     22/7/2021     21/7/2021   ชาย  29.0  วัน     Burmese
# 286044  286045      5/7/2021      4/7/2021   ชาย  29.0  วัน   Cambodian
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# Quiz 10
# หา records ต่อไปนี้
#
# ~records ที่ กักตัวที่ขอนแก่น~ Oil
#
# ~records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร~ Kie
#
# ~records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม~ Kie
#
# ~records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่~ Nicha

# %% [markdown]
# records ที่ กักตัวที่ขอนแก่น

# %%
data_cases[data_cases['province_of_isolation']=='ขอนแก่น']
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี    Thailand
# 463        464     22/3/2020     21/3/2020  หญิง  36.0   ปี    Thailand
# 1467      1468     30/3/2020     26/3/2020   ชาย  19.0   ปี    Thailand
# 1971      1972      3/4/2020     31/3/2020  หญิง  70.0   ปี    Thailand
# 2638      2639     15/4/2020     14/4/2020  หญิง  63.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839669  839670     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 839670  839671     12/8/2021     11/8/2021   ชาย  58.0   ปี    Thailand
# 839671  839672     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839672  839673     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
# 839673  839674     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# ...

# %% [markdown]
# records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร

# %%
data_cases[(data_cases['province_of_isolation']=='ขอนแก่น') | (data_cases['province_of_isolation']=='นครราชสีมา') |
           (data_cases['province_of_isolation']=='อุดรธานี')]
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี    Thailand
# 189        190     18/3/2020     16/3/2020   ชาย  57.0   ปี    Thailand
# 207        208     18/3/2020     16/3/2020  หญิง  30.0   ปี    Thailand
# 212        213     18/3/2020     14/3/2020  หญิง  22.0   ปี    Thailand
# 284        285     20/3/2020     17/3/2020   ชาย  42.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839669  839670     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 839670  839671     12/8/2021     11/8/2021   ชาย  58.0   ปี    Thailand
# 839671  839672     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839672  839673     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
# 839673  839674     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# ...

# %% [markdown]
# records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม

# %%
data_cases[(data_cases['province_of_onset']=='กรุงเทพมหานคร') & (data_cases['sex']=='หญิง')]
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# 5            6     25/1/2020    99/99/9999  หญิง  33.0   ปี       China
# 6            7     26/1/2020    99/99/9999  หญิง  57.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839380  839381     12/8/2021     11/8/2021  หญิง  53.0   ปี    Thailand
# 839386  839387     12/8/2021     11/8/2021  หญิง  78.0   ปี    Thailand
# 839391  839392     12/8/2021     11/8/2021  หญิง  83.0   ปี    Thailand
# 839393  839394     12/8/2021     11/8/2021  หญิง  43.0   ปี    Thailand
# 839394  839395     12/8/2021     11/8/2021  หญิง  74.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# ...

# %% [markdown]
# records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่

# %%
data_cases[(data_cases['province_of_isolation']=='เชียงใหม่') &
           (data_cases['sex']=='ชาย') &
           (data_cases['age']>=18) &
           (data_cases['age']<=22)].sort_values(by='age')
# Out:
#          No. announce_date Notified date  sex   age Unit nationality  \
# 56211  56212     26/4/2021     25/4/2021  ชาย  18.0   ปี    Thailand
# 37293  37294     15/4/2021     14/4/2021  ชาย  18.0   ปี    Thailand
# 54198  54199     25/4/2021     24/4/2021  ชาย  18.0   ปี         NaN
# 54121  54122     25/4/2021     24/4/2021  ชาย  18.0   ปี         NaN
# 66258  66259      1/5/2021     30/4/2021  ชาย  18.0   ปี    Thailand
# ...      ...           ...           ...  ...   ...  ...         ...
# 54251  54252     25/4/2021     24/4/2021  ชาย  22.0   ปี         NaN
# 34486  34487     13/4/2021     12/4/2021  ชาย  22.0   ปี         NaN
# 34481  34482     13/4/2021     12/4/2021  ชาย  22.0   ปี         NaN
# 52549  52550     24/4/2021     23/4/2021  ชาย  22.0   ปี    Thailand
# 37450  37451     15/4/2021     14/4/2021  ชาย  22.0   ปี    Thailand
#
#       province_of_isolation                                              risk  \
# ...

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(data_cases['Unit'].dropna())
# Out:
# (array([7.6117e+05, 0.0000e+00, 2.4140e+03, 0.0000e+00, 0.0000e+00,
#         1.3900e+02, 0.0000e+00, 2.2000e+01, 0.0000e+00, 1.0000e+00]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
data_cases[['Unit']] = data_cases[['Unit']].fillna('ปี')

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['nationality']] = data_cases[['nationality']].fillna('ไทย?')

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# ## Handling Missing Value 3 แทนด้วยค่าด้วยค่ากลาง

# %%
data_cases[['age']] = data_cases[['age']].fillna(data_cases['age'].mean())

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['sex']] = data_cases[['sex']].fillna('นาย')
data_cases[['sex']]
# Out:
#          sex
# 0       หญิง
# 1       หญิง
# 2       หญิง
# 3        ชาย
# 4       หญิง
# ...      ...
# 839766   ชาย
# 839767   ชาย
# 839768   ชาย
# 839769   ชาย
# 839770   ชาย
#
# [839771 rows x 1 columns]

# %%
set(data_cases['sex'])
# Out:
# {'ชาย', 'นาย', 'หญิง'}

# %%
data_cases[['sex']].dropna().mode()
# Out:
#     sex
# 0  หญิง

# %%
sex_mode = data_cases[['sex']].dropna().mode().iloc[0,0]
sex_mode
# Out:
# 'หญิง'

# %%
data_cases[['sex']] = data_cases[['sex']].fillna(data_cases[['sex']].dropna().mode().iloc[0,0])
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ## Loop [PD]

# %%
for i in range(10):
    print(data_cases.iloc[i,:])
    print('------------------new line---------------')
# Out:
# No.                                                     1
# announce_date                                   12/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  61.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 0, dtype: object
# ------------------new line---------------
# No.                                                     2
# announce_date                                   17/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# ...

# %%
for record in data_cases.iloc[:10,:].iterrows():
    print(record)
    print('------------------new line---------------')
# Out:
# (0, No.                                                     1
# announce_date                                   12/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  61.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 0, dtype: object)
# ------------------new line---------------
# (1, No.                                                     2
# announce_date                                   17/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# ...

# %%
f = ["apple","papaya"]
for i in enumerate(f):
    print(i)
for i in range(len(f)):
    print(f)
# Out:
# (0, 'apple')
# (1, 'papaya')
# ['apple', 'papaya']
# ['apple', 'papaya']

# %% [markdown]
# ## เราสามารถกำหนดค่าให้กับตารางทีละ column หรือสร้าง
# ## column ใหม่ให้กับตาราง ได้โดยใช้ list ที่มีจำนวนเท่ากับจำนวน record

# %%
data_cases['new col'] = list(range(data_cases.shape[0]))

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# # แก้ missing ใน province_of_isolation เติมค่าของ onset ใน isolation ก่อนจะเติมค่า mode

# %%
new_p_iso = list()

for row in data_cases.iterrows():
    if pd.isna(row[1]['province_of_isolation']):
        if pd.isna(row[1]['province_of_onset']) == False:
            new_p_iso.append(row[1]['province_of_onset'])
        else:
            new_p_iso.append(data_cases[['province_of_isolation']].dropna().mode().iloc[0,0])
    else:
        new_p_iso.append(row[1]['province_of_isolation'])

# %%
len(new_p_iso)
# Out:
# 839771

# %%
data_cases['province_of_isolation'] = new_p_iso

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
data_cases2 = pd.read_csv(path)
# Out:
# <ipython-input-80-f63be545a78f>:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_cases2 = pd.read_csv(path)

# %%
data_cases2[pd.isna(data_cases2['province_of_isolation'])]
# Out:
#          No. announce_date Notified date   sex   age Unit nationality  \
# 39        40     26/2/2020           NaN   ชาย   8.0   ปี    Thailand
# 40        41     28/2/2020           NaN   ชาย  25.0   ปี    Thailand
# 41        42     29/2/2020           NaN   ชาย  21.0   ปี    Thailand
# 42        43      2/3/2020           NaN  หญิง  22.0   ปี    Thailand
# 140      141     16/3/2020           NaN  หญิง  50.0   ปี    Thailand
# ...      ...           ...           ...   ...   ...  ...         ...
# 40814  40815     18/4/2021     17/4/2021   ชาย  29.0   ปี    Thailand
# 40815  40816     18/4/2021     17/4/2021   ชาย  37.0   ปี    Thailand
# 40816  40817     18/4/2021     17/4/2021  หญิง  61.0   ปี    Thailand
# 40829  40830     18/4/2021     17/4/2021   ชาย  37.0   ปี     Nigeria
# 40830  40831     18/4/2021     17/4/2021   ชาย  36.0   ปี    Thailand
#
#       province_of_isolation  \
# 39                      NaN
# 40                      NaN
# 41                      NaN
# ...

# %%
data_cases[pd.isna(data_cases2['province_of_isolation'])]
# Out:
#          No. announce_date Notified date   sex   age Unit nationality  \
# 39        40     26/2/2020    99/99/9999   ชาย   8.0   ปี    Thailand
# 40        41     28/2/2020    99/99/9999   ชาย  25.0   ปี    Thailand
# 41        42     29/2/2020    99/99/9999   ชาย  21.0   ปี    Thailand
# 42        43      2/3/2020    99/99/9999  หญิง  22.0   ปี    Thailand
# 140      141     16/3/2020    99/99/9999  หญิง  50.0   ปี    Thailand
# ...      ...           ...           ...   ...   ...  ...         ...
# 40814  40815     18/4/2021     17/4/2021   ชาย  29.0   ปี    Thailand
# 40815  40816     18/4/2021     17/4/2021   ชาย  37.0   ปี    Thailand
# 40816  40817     18/4/2021     17/4/2021  หญิง  61.0   ปี    Thailand
# 40829  40830     18/4/2021     17/4/2021   ชาย  37.0   ปี     Nigeria
# 40830  40831     18/4/2021     17/4/2021   ชาย  36.0   ปี    Thailand
#
#       province_of_isolation  \
# 39            กรุงเทพมหานคร
# 40                  นนทบุรี
# 41            กรุงเทพมหานคร
# ...

# %% [markdown]
# ## Handling Missing Value 4 แทนด้วยค่าด้วยค่ากลางของกลุ่ม

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
risk_list = list(set(data_cases['risk']))
print(risk_list)
# Out:
# ['Cluster บ่อนไก่อ่างทอง', 'มาจากพื้นที่เสี่ยง', 'Cluster ชลบุรี', 'Cluster ตราด ', 'Cluster จันทบุรี (ชาวกินี)', 'Cluster จันทบุรี', 'Cluster ตลาดบางแค', 'แรงงานต่างด้าวตรวจก่อนขึ้นทะเบียน', 'ไปแหล่งชุมชน/สถานที่คนหนาแน่น', 'Cluster จันทบุรี (ชาวกินี )', 'อยู่ระหว่างสอบสวน', 'Cluster คลองเตย', 'ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ', 'สัมผัสในสถานพยาบาล', 'ผู้ป่วย กรุงเทพมหานคร', 'เดินทางมาจากพื้นที่มีการระบาดของโรค', 'สัมผัสผู้ป่วยยืนยันเพื่อนร่วมงาน', 'มาจากพื้นที่เสี่ยง จ.ปทุมธานี', 'Cluster ผับ Thonglor', 'สัมผัสใกล้ชิดผู้ป่วยยันยันก่อนหน้า', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ', 'Cluster มหาสารคาม', 'สัมผัสใกล้ชิดผู้ป่วยยืนยันก่อนหน้า', 'ผู้ป่วย PUI', 'Cluster โรงงานทำขนม บางขุนเทียน', 'Cluster ห้างแสงทอง (สายล่าง)', 'Cluster บ่อนพัทยา/ชลบุรี', 'ACF สีลม', nan, 'cluster ชลบุรี\n(อยู่ระหว่างการสอบสวน)', 'ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต', 'Cluster สมุทรปราการ ตลาดเคหะบางพลี', '2.สัมผัสผู้ติดเชื้อ', 'ค้นหาเชิงรุ
# ...

# %% [markdown]
# ทำของขอนแก่น

# %%
dataKK = data_cases[data_cases['province_of_onset']=='ขอนแก่น']

# %%
dataKK[['risk']] = dataKK[['risk']].fillna(dataKK[['risk']].dropna().mode().iloc[0,0])
dataKK[['risk']]
# Out:
# <ipython-input-86-bdb3eb6a1837>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataKK[['risk']] = dataKK[['risk']].fillna(dataKK[['risk']].dropna().mode().iloc[0,0])
#                                                  risk
# 181                                           สนามมวย
# 463       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1467                    คนไทยเดินทางกลับจากต่างประเทศ
# 1971    ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2638                    สัมผัสผู้เดินทางจากต่างประเทศ
# ...                                               ...
# 839669                               ทัณฑสถาน/เรือนจำ
# 839670                               ทัณฑสถาน/เรือนจำ
# 839671                               ทัณฑสถาน/เรือนจำ
# ...

# %%
dataKK
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี    Thailand
# 463        464     22/3/2020     21/3/2020  หญิง  36.0   ปี    Thailand
# 1467      1468     30/3/2020     26/3/2020   ชาย  19.0   ปี    Thailand
# 1971      1972      3/4/2020     31/3/2020  หญิง  70.0   ปี    Thailand
# 2638      2639     15/4/2020     14/4/2020  หญิง  63.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839669  839670     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 839670  839671     12/8/2021     11/8/2021   ชาย  58.0   ปี    Thailand
# 839671  839672     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839672  839673     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
# 839673  839674     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# ...

# %%
dataKK[['risk']].dropna().mode().iloc[0,0]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %%
dataKK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
dataCN = data_cases[data_cases['province_of_onset']=='ชลบุรี']

# %%
dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# Out:
# <ipython-input-91-61c7282d7081>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])

# %%
dataCN
# Out:
#            No. announce_date Notified date  sex   age Unit nationality  \
# 31          32      8/2/2020    99/99/9999  ชาย  24.0   ปี    Thailand
# 43          44      5/3/2020    99/99/9999  ชาย  29.0   ปี       Italy
# 44          45      5/3/2020    99/99/9999  ชาย  41.0   ปี    Thailand
# 154        155     17/3/2020    99/99/9999  ชาย  61.0   ปี    Thailand
# 222        223     19/3/2020    99/99/9999  ชาย  63.0   ปี    Thailand
# ...        ...           ...           ...  ...   ...  ...         ...
# 839468  839469     12/8/2021     11/8/2021  ชาย  29.0   ปี    Thailand
# 839469  839470     12/8/2021     11/8/2021  ชาย  34.0   ปี    Thailand
# 839470  839471     12/8/2021     11/8/2021  ชาย  21.0   ปี    Thailand
# 839471  839472     12/8/2021     11/8/2021  ชาย  30.0   ปี    Thailand
# 839472  839473     12/8/2021     11/8/2021  ชาย  35.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
dataCN[['risk']].dropna().mode().iloc[0,0]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %% [markdown]
# ## [PD] ต่อตาราง แกน Y

# %%
dataKKCN = pd.concat([dataKK,dataCN])
dataKKCN
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี    Thailand
# 463        464     22/3/2020     21/3/2020  หญิง  36.0   ปี    Thailand
# 1467      1468     30/3/2020     26/3/2020   ชาย  19.0   ปี    Thailand
# 1971      1972      3/4/2020     31/3/2020  หญิง  70.0   ปี    Thailand
# 2638      2639     15/4/2020     14/4/2020  หญิง  63.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839468  839469     12/8/2021     11/8/2021   ชาย  29.0   ปี    Thailand
# 839469  839470     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839470  839471     12/8/2021     11/8/2021   ชาย  21.0   ปี    Thailand
# 839471  839472     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839472  839473     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# ...

# %%
X = list(set(data_cases['province_of_onset']))
X
# Out:
# ['สุราษฎร์ธานี',
#  'ท้ายบ้าน',
#  'นครปบม',
#  'สมุุทรปราการ',
#  'บางกะปิ',
#  'เชียงราย',
#  'กาฬสินธ์',
#  'บุรีรัยม์',
#  'สมทรสาคร',
#  'สุทรปราการ',
#  'นครศร๊ะรรมราช',
#  'ปทุมธานี.',
#  'นนทบุรี',
#  'มาเลเซีย',
#  'นครพนม',
#  'สมุุทรสาคร',
#  'ปัตตานี',
#  'ยะลา',
#  'วังชิ้น',
#  '\xa0ตราด',
#  'เชีียงราย',
#  'สูงเม่น',
#  'ชลบุรี',
#  'นครนาชสีมา',
#  'อยุทธยา',
#  'นครปฐม',
#  'กาญจนบุรี',
#  'สิงห์บุรี',
#  'หนองบัวลำภู',
#  'เรือ',
#  'ยโสธร',
#  'ลาดพร้าว',
#  'สุมุทรสาคร',
#  'นอกเขต',
#  'พิษณูโลก',
#  'ลอง',
#  'มหาสาคาม',
#  '\xa0ชลบุรี',
#  'อำนาจเจริญ',
#  'อยุธยา',
#  nan,
#  'ปลายพระยา',
#  'บ้านหลวง',
#  'ลำปาง',
#  'ไม่ระบุ',
#  'สุมทรปราการ',
#  'นตรปฐม',
#  'กัมพูชา',
#  'กาฬสินธุ์',
#  'อุบลราชธานี',
#  'ชลบุรี\t',
#  'ลำพูน',
#  '\xa0นครปฐม',
#  'นครนายก',
#  'สมุทรสาคร',
#  'อุุทัยธานี',
#  'ปมุมธานี',
#  'อํานาจเจริญ',
#  'กรุงเทพมหานคร',
#  'สมุทรปรากรร',
#  'อุุดรธานี',
#  'หนองม่วงไข่',
#  'ระนอง',
#  'พระนครศรีอยุธยา',
#  'สะแก้ว',
#  'ธารโต',
# ...

# %%
dataCN = data_cases[data_cases['province_of_onset']==X[0]]

# %%
dataCN
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 161        162     17/3/2020     21/3/2020   ชาย  14.0   ปี    Thailand
# 176        177     17/3/2020    99/99/9999   ชาย  49.0   ปี    Thailand
# 248        249     19/3/2020    99/99/9999  หญิง  26.0   ปี     Belgium
# 333        334     21/3/2020     20/3/2020   ชาย  53.0   ปี    Thailand
# 334        335     21/3/2020     20/3/2020   ชาย  20.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 833371  833372     12/8/2021     11/8/2021   ชาย  50.0   ปี      German
# 833372  833373     12/8/2021     11/8/2021  หญิง  51.0   ปี    Thailand
# 833373  833374     12/8/2021     11/8/2021  หญิง  22.0   ปี    Thailand
# 833374  833375     12/8/2021     11/8/2021   ชาย  49.0   ปี    Thailand
# 833375  833376     12/8/2021     11/8/2021  หญิง  48.0   ปี    Thailand
#
#        province_of_isolation                                         risk  \
# ...

# %%
prov_list = list()
for e_province in list(set(data_cases['province_of_onset']))[1:]:
    print(e_province)
    dataCN = data_cases[data_cases['province_of_onset']==e_province]
    print(dataCN[['risk']])
    dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
    prov_list.append(dataCN) ##
dataALL = pd.concat(prov_list)
# Out:
# ท้ายบ้าน
#          risk
# 704885  อื่นๆ
# นครปบม
#          risk
# 727065  อื่นๆ
# สมุุทรปราการ
#                                                risk
# 636971  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 704924                                        อื่นๆ
# 780786  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 781357                                        อื่นๆ
# 781871                                        อื่นๆ
# 781872                                        อื่นๆ
# 781873                                        อื่นๆ
# บางกะปิ
# <ipython-input-98-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# ...

# %%
prov_list = list()
for e_province in list(set(data_cases['province_of_onset']))[1:]:
    print(e_province)
    dataCN = data_cases[data_cases['province_of_onset']==e_province]
    if all(dataCN[['risk']].isna()):
        dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
    else:
        dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
    prov_list.append(dataCN) ##
dataALL = pd.concat(prov_list)
# Out:
# ท้ายบ้าน
# <ipython-input-99-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นครปบม
# <ipython-input-99-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-99-9ae0a19cef65>:6: SettingWithCopyWarning:
# ...

# %%
dataALL
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 704885  704886      6/8/2021      5/8/2021   ชาย  47.0   ปี        ไทย?
# 727065  727066      7/8/2021      6/8/2021  หญิง  34.0   ปี        ไทย?
# 636971  636972      3/8/2021      2/8/2021  หญิง  40.0   ปี    Thailand
# 704924  704925      6/8/2021      5/8/2021  หญิง  39.0   ปี        ไทย?
# 780786  780787     10/8/2021      9/8/2021   ชาย  36.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 832154  832155     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
# 832166  832167     12/8/2021     11/8/2021   ชาย  10.0   ปี    Thailand
# 832179  832180     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 837021  837022     12/8/2021     11/8/2021   นาย  33.0   ปี        ไทย?
# 666341  666342      4/8/2021      3/8/2021  หญิง  67.0   ปี    Thailand
#
#        province_of_isolation                                         risk  \
# ...

# %%
datamissingonset = data_cases[pd.isna(data_cases['province_of_onset'])]
datamissingonset
# Out:
#            No. announce_date Notified date   sex        age Unit nationality  \
# 415        416     22/3/2020     22/3/2020   ชาย  29.000000   ปี    Thailand
# 530        531     22/3/2020     20/3/2020   ชาย  37.000000   ปี    Thailand
# 556        557     22/3/2020     21/3/2020  หญิง   6.000000   ปี    Thailand
# 577        578     22/3/2020     20/3/2020   ชาย  35.700109   ปี    Thailand
# 589        590     22/3/2020     21/3/2020   ชาย  35.700109   ปี    Thailand
# ...        ...           ...           ...   ...        ...  ...         ...
# 838196  838197     12/8/2021     11/8/2021   นาย  36.000000   ปี        ไทย?
# 838371  838372     12/8/2021     11/8/2021   ชาย  28.000000   ปี   Cambodian
# 838395  838396     12/8/2021     11/8/2021   ชาย  45.000000   ปี   Cambodian
# 839144  839145     12/8/2021     11/8/2021   ชาย  76.000000   ปี    Thailand
# 839304  839305     12/8/2021     11/8/2021   นาย  35.700109   ปี        ไทย?
#
# ...

# %%
datamissingonset[['risk']] = datamissingonset[['risk']].fillna(datamissingonset[['risk']].dropna().mode().iloc[0,0])
# Out:
# <ipython-input-102-38d97297ccf5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datamissingonset[['risk']] = datamissingonset[['risk']].fillna(datamissingonset[['risk']].dropna().mode().iloc[0,0])

# %%
dataALL = pd.concat([dataALL,datamissingonset])

# %%
dataALL
# Out:
#            No. announce_date Notified date   sex        age Unit nationality  \
# 704885  704886      6/8/2021      5/8/2021   ชาย  47.000000   ปี        ไทย?
# 727065  727066      7/8/2021      6/8/2021  หญิง  34.000000   ปี        ไทย?
# 636971  636972      3/8/2021      2/8/2021  หญิง  40.000000   ปี    Thailand
# 704924  704925      6/8/2021      5/8/2021  หญิง  39.000000   ปี        ไทย?
# 780786  780787     10/8/2021      9/8/2021   ชาย  36.000000   ปี    Thailand
# ...        ...           ...           ...   ...        ...  ...         ...
# 838196  838197     12/8/2021     11/8/2021   นาย  36.000000   ปี        ไทย?
# 838371  838372     12/8/2021     11/8/2021   ชาย  28.000000   ปี   Cambodian
# 838395  838396     12/8/2021     11/8/2021   ชาย  45.000000   ปี   Cambodian
# 839144  839145     12/8/2021     11/8/2021   ชาย  76.000000   ปี    Thailand
# 839304  839305     12/8/2021     11/8/2021   นาย  35.700109   ปี        ไทย?
#
# ...

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
dataALL.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
dataALL = dataALL.sort_values(by='No.')
dataALL
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
dataALL.keys()
# Out:
# Index(['No.', 'announce_date', 'Notified date', 'sex', 'age', 'Unit',
#        'nationality', 'province_of_isolation', 'risk', 'province_of_onset',
#        'district_of_onset', 'new col'],
#       dtype='object')

# %% [markdown]
# ## การทำงานกับ Datetime-Timestamp
#
# https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587
#
# https://realpython.com/python-datetime/

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
data_cases.sort_values(by=['announce_date']).iloc[270:290]
# Out:
#        No. announce_date Notified date   sex        age Unit     nationality  \
# 7073  7074      1/1/2021    31/12/2020  หญิง  35.700109   ปี        Thailand
# 7072  7073      1/1/2021    31/12/2020   นาย  35.700109   ปี           Burma
# 7071  7072      1/1/2021    31/12/2020  หญิง  35.700109   ปี        Thailand
# 7065  7066      1/1/2021    31/12/2020   ชาย  35.700109   ปี        Thailand
# 7069  7070      1/1/2021    31/12/2020   ชาย  35.700109   ปี        Thailand
# 7068  7069      1/1/2021    31/12/2020   ชาย  35.700109   ปี        Thailand
# 7067  7068      1/1/2021    31/12/2020  หญิง  35.700109   ปี        Thailand
# 7093  7094      1/1/2021    31/12/2020   ชาย  35.700109   ปี        Thailand
# 7066  7067      1/1/2021    31/12/2020  หญิง  35.700109   ปี        Thailand
# 3567  3568     1/10/2020     30/9/2020   ชาย  41.000000   ปี           India
# 3566  3567     1/10/2020     30/9/2020   ชาย  48.000000   ปี        Thailand
# ...

# %%
from datetime import datetime

# %%
data_cases.iloc[0,1]
# Out:
# '12/1/2020'

# %%
t = pd.to_datetime(data_cases.iloc[0,1])
t
# Out:
# Timestamp('2020-12-01 00:00:00')

# %%
t = pd.to_datetime(data_cases.iloc[0,1],dayfirst=True)
t
# Out:
# Timestamp('2020-01-12 00:00:00')

# %%
data_cases['announce_date']=pd.to_datetime(data_cases['announce_date'])
# Out:
# <ipython-input-115-86b04c1e170e>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data_cases['announce_date']=pd.to_datetime(data_cases['announce_date'])

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-12-01    99/99/9999  หญิง  61.0   ปี       China
# 1            2    2020-01-17    99/99/9999  หญิง  74.0   ปี       China
# 2            3    2020-01-22    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22    99/99/9999   ชาย  68.0   ปี       China
# 4            5    2020-01-24    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767    2021-12-08     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768    2021-12-08     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769    2021-12-08     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770    2021-12-08     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771    2021-12-08     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
dataALL['announce_date']=pd.to_datetime(dataALL['announce_date'],dayfirst=True)

# %%
dataALL
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-01-12    99/99/9999  หญิง  61.0   ปี       China
# 1            2    2020-01-17    99/99/9999  หญิง  74.0   ปี       China
# 2            3    2020-01-22    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22    99/99/9999   ชาย  68.0   ปี       China
# 4            5    2020-01-24    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767    2021-08-12     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768    2021-08-12     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769    2021-08-12     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770    2021-08-12     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771    2021-08-12     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
dataALL[dataALL['announce_date']==datetime(day=13,month=4,year=2020)]
# Out:
#        No. announce_date Notified date   sex        age Unit  nationality  \
# 2552  2553    2020-04-13     12/4/2020   ชาย  20.000000   ปี     Thailand
# 2553  2554    2020-04-13     12/4/2020   ชาย  24.000000   ปี     Thailand
# 2554  2555    2020-04-13     12/4/2020   ชาย  58.000000   ปี     Thailand
# 2555  2556    2020-04-13     12/4/2020  หญิง  34.000000   ปี     Thailand
# 2556  2557    2020-04-13     12/4/2020  หญิง  38.000000   ปี     Thailand
# 2557  2558    2020-04-13     12/4/2020   ชาย  31.000000   ปี     Thailand
# 2558  2559    2020-04-13     12/4/2020  หญิง  59.000000   ปี     Thailand
# 2559  2560    2020-04-13     12/4/2020   ชาย  70.000000   ปี     Thailand
# 2560  2561    2020-04-13     12/4/2020  หญิง  40.000000   ปี     Thailand
# 2561  2562    2020-04-13     12/4/2020  หญิง  50.000000   ปี     Thailand
# 2562  2563    2020-04-13     12/4/2020  หญิง  49.000000   ปี     Thailand
# 2563  2564    2020-04-13     12/4/2020  หญิง  31.000000   ปี     Thailand
# ...

# %%
dataALL[(dataALL['announce_date']>=datetime(day=13,month=4,year=2020)) & (dataALL['announce_date']<=datetime(day=15,month=4,year=2020))]
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 2552  2553    2020-04-13     12/4/2020   ชาย  20.0   ปี    Thailand
# 2553  2554    2020-04-13     12/4/2020   ชาย  24.0   ปี    Thailand
# 2554  2555    2020-04-13     12/4/2020   ชาย  58.0   ปี    Thailand
# 2555  2556    2020-04-13     12/4/2020  หญิง  34.0   ปี    Thailand
# 2556  2557    2020-04-13     12/4/2020  หญิง  38.0   ปี    Thailand
# ...    ...           ...           ...   ...   ...  ...         ...
# 2639  2640    2020-04-15     14/4/2020   ชาย  72.0   ปี    Thailand
# 2640  2641    2020-04-15     14/4/2020  หญิง  34.0   ปี    Thailand
# 2641  2642    2020-04-15     14/4/2020  หญิง  53.0   ปี    Thailand
# 2642  2643    2020-04-15     14/4/2020  หญิง  43.0   ปี       Burma
# 2643  2644    2020-04-15     14/4/2020   ชาย  30.0   ปี    Thailand
#
#      province_of_isolation                                         risk  \
# 2552                ภูเก็ต  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %% [markdown]
# # Smooth data by Binning

# %%
dataALL.iloc[2000:2500,4]
# Out:
# 2015    45.0
# 2016    33.0
# 2017    57.0
# 2018    40.0
# 2019    36.0
#         ...
# 2514    43.0
# 2515    40.0
# 2516    44.0
# 2517    48.0
# 2518    29.0
# Name: age, Length: 500, dtype: float64

# %%
my_data = dataALL.iloc[2000:2500,4]

# %%
plt.scatter(range(len(my_data)),my_data)

# %% [markdown]
# ### Sort

# %%
my_data_sorted = my_data.sort_values()

# %%
my_data_sorted
# Out:
# 2455     1.0
# 2259     1.0
# 2448     2.0
# 2376     3.0
# 2476     3.0
#         ...
# 2494    75.0
# 2337    77.0
# 2219    78.0
# 2183    81.0
# 2483    91.0
# Name: age, Length: 500, dtype: float64

# %%
plt.scatter(range(len(my_data)),my_data_sorted)

# %% [markdown]
# ### Bin - Rep

# %%
import numpy as np

# %% [markdown]
# * 0  :50     i=0   50*i : (50*i)+50
# * 50 :100    i=1   50*i : (50*i)+50
# * 100:150    i=2   50*i : (50*i)+50

# %%
bin = 10
bin_r = list()
step = int(len(my_data_sorted)/bin)
for i in range(bin):
    this_data = my_data_sorted[(step*i):(step*i)+step]    #ตัดข้อมูล
    rep = np.mean(this_data)   #เลือกตัวแทน
    bin_r.append(rep)

# %%
list(range(0,len(my_data_sorted),50))
# Out:
# [0, 50, 100, 150, 200, 250, 300, 350, 400, 450]

# %%
bin = 10
bin_r = list()
step = int(len(my_data_sorted)/bin)
for start in range(0,len(my_data_sorted),50):
    this_data = my_data_sorted[start:start+step]    #ตัดข้อมูล
    rep = np.mean(this_data)  #เลือกตัวแทน
    bin_r.append(rep)

# %%
bin_r
# Out:
# [15.22,
#  24.14,
#  28.38,
#  32.38,
#  35.856008680927964,
#  39.04,
#  43.68,
#  49.56,
#  56.64,
#  67.5]

# %% [markdown]
# ### Smooth

# %%
my_data_smoothed = list()
step = 0
this_bin = 0
for i in my_data_sorted:
    if step < 50:
        my_data_smoothed.append({'old_v':i,'new_v':bin_r[this_bin]})
        step = step + 1
    else:
        step = 0
        this_bin = this_bin + 1
        my_data_smoothed.append({'old_v':i,'new_v':bin_r[this_bin]})

# %%
my_data_smoothed
# Out:
# [{'old_v': 1.0, 'new_v': 15.22},
#  {'old_v': 1.0, 'new_v': 15.22},
#  {'old_v': 2.0, 'new_v': 15.22},
#  {'old_v': 3.0, 'new_v': 15.22},
#  {'old_v': 3.0, 'new_v': 15.22},
#  {'old_v': 4.0, 'new_v': 15.22},
#  {'old_v': 5.0, 'new_v': 15.22},
#  {'old_v': 5.0, 'new_v': 15.22},
#  {'old_v': 7.0, 'new_v': 15.22},
#  {'old_v': 7.0, 'new_v': 15.22},
#  {'old_v': 8.0, 'new_v': 15.22},
#  {'old_v': 9.0, 'new_v': 15.22},
#  {'old_v': 10.0, 'new_v': 15.22},
#  {'old_v': 11.0, 'new_v': 15.22},
#  {'old_v': 11.0, 'new_v': 15.22},
#  {'old_v': 13.0, 'new_v': 15.22},
#  {'old_v': 13.0, 'new_v': 15.22},
#  {'old_v': 15.0, 'new_v': 15.22},
#  {'old_v': 15.0, 'new_v': 15.22},
#  {'old_v': 15.0, 'new_v': 15.22},
#  {'old_v': 16.0, 'new_v': 15.22},
#  {'old_v': 17.0, 'new_v': 15.22},
#  {'old_v': 17.0, 'new_v': 15.22},
#  {'old_v': 18.0, 'new_v': 15.22},
#  {'old_v': 18.0, 'new_v': 15.22},
#  {'old_v': 19.0, 'new_v': 15.22},
#  {'old_v': 19.0, 'new_v': 15.22},
#  {'old_v': 19.0, 'new_v': 15.22},
# ...

# %%
my_df = pd.DataFrame(my_data_smoothed) #แปลง Dict เป็น ตาราง pandas (ยังไม่ได้สอน)
my_df
# Out:
#      old_v  new_v
# 0      1.0  15.22
# 1      1.0  15.22
# 2      2.0  15.22
# 3      3.0  15.22
# 4      3.0  15.22
# ..     ...    ...
# 495   75.0  67.50
# 496   77.0  67.50
# 497   78.0  67.50
# 498   81.0  67.50
# 499   91.0  67.50
#
# [500 rows x 2 columns]

# %%
plt.scatter(range(len(my_data)),my_df['new_v'])

# %% [markdown]
# ## แทนค่ากลับลงไปในตาราง

# %% [markdown]
# # การต่อตาราง (แนวแกน X)

# %% [markdown]
# หาจำนวนร้านค้าที่แสดงเป็นอันดับ 1-4 ที่ถูกกดเข้าไปดูหลังจาก search โดยร้านค้านั้นตั้งอยู่ที่เชียงใหม่

# %%
w_res = pd.read_csv(os.path.join(path,'w_restaurant.csv'))
w_res.head()
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-136-1e10d543b845> in <cell line: 1>()
# ----> 1 w_res = pd.read_csv(os.path.join(path,'w_restaurant.csv'))
#       2 w_res.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
search_click = pd.read_csv(os.path.join(path,'search_click.csv'))
search_click.head()
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-137-1afefc00ec0c> in <cell line: 1>()
# ----> 1 search_click = pd.read_csv(os.path.join(path,'search_click.csv'))
#       2 search_click.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import numpy as np

# %%
np.random.choice(['นิชา','oil','กี้'])

# %% [markdown]
# หาร้านที่ตั้งอยู่ที่ จ.เชียงใหม่

# %%
w_res[w_res['city_name']=='Chiang Mai']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-c0b0a5f83da6> in <cell line: 1>()
# ----> 1 w_res[w_res['city_name']=='Chiang Mai']
#
# NameError: name 'w_res' is not defined

# %% [markdown]
# หา records ที่ถูก click เวลา 4-6 โมงเย็น

# %% [markdown]
# ตรวจสอบชนิดข้อมูล

# %%
search_click.iloc[0,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-6127705031d6> in <cell line: 1>()
# ----> 1 search_click.iloc[0,0]
#
# NameError: name 'search_click' is not defined

# %% [markdown]
# แปลงให้เป็น datetime

# %%
from datetime import datetime

# %%
pd.to_datetime(search_click.iloc[0,0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-143-dceb628f6a19> in <cell line: 1>()
# ----> 1 pd.to_datetime(search_click.iloc[0,0])
#
# NameError: name 'search_click' is not defined

# %%
#ไม่มีข้อมูล timestamp

# %% [markdown]
# records ที่ถูกแสดงเป็นอันดับที่ 1-4

# %%
search_click[(search_click['display_position']>=0)&(search_click['display_position']<=3)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-46d7374fe3a7> in <cell line: 1>()
# ----> 1 search_click[(search_click['display_position']>=0)&(search_click['display_position']<=3)]
#
# NameError: name 'search_click' is not defined

# %% [markdown]
# จำนวนร้าน ที่ถูกแสดงเป็นอันดับที่ 1-4

# %%
search_click_14 = search_click[(search_click['display_position']>=0)&(search_click['display_position']<=3)].drop_duplicates(subset=['business_id'])
search_click_14
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-a9e7c942a650> in <cell line: 1>()
# ----> 1 search_click_14 = search_click[(search_click['display_position']>=0)&(search_click['display_position']<=3)].drop_duplicates(subset=['business_id'])
#       2 search_click_14
#
# NameError: name 'search_click' is not defined

# %% [markdown]
# # การต่อตารางแนวแกน X มี 2 คำสั่ง
# * merge two table(.merge())
#
# * copy a column from other table (.map()) คล้าย ๆ merge แต่ดึงมาแค่บางคอลัมน์

# %% [markdown]
# Merge()

# %% [markdown]
# Map()

# %% [markdown]
# ## ต่อ Smooth by Binning

# %%
dataALL_cut = dataALL.iloc[2000:2500,:5]
dataALL_cut
# Out:
#        No. announce_date Notified date   sex   age
# 2015  2016    2020-04-04      3/4/2020  หญิง  45.0
# 2016  2017    2020-04-04      3/4/2020   ชาย  33.0
# 2017  2018    2020-04-04      3/4/2020   ชาย  57.0
# 2018  2019    2020-04-04      3/4/2020   ชาย  40.0
# 2019  2020    2020-04-04      3/4/2020   ชาย  36.0
# ...    ...           ...           ...   ...   ...
# 2514  2515    2020-04-11     10/4/2020   ชาย  43.0
# 2515  2516    2020-04-11     10/4/2020   ชาย  40.0
# 2516  2517    2020-04-11     10/4/2020   ชาย  44.0
# 2517  2518    2020-04-11     10/4/2020   ชาย  48.0
# 2518  2519    2020-04-11     10/4/2020   ชาย  29.0
#
# [500 rows x 5 columns]

# %%
my_df
# Out:
#      old_v  new_v
# 0      1.0  15.22
# 1      1.0  15.22
# 2      2.0  15.22
# 3      3.0  15.22
# 4      3.0  15.22
# ..     ...    ...
# 495   75.0  67.50
# 496   77.0  67.50
# 497   78.0  67.50
# 498   81.0  67.50
# 499   91.0  67.50
#
# [500 rows x 2 columns]

# %%
my_df_unique = my_df.drop_duplicates(subset=['old_v'])
my_df_unique
# Out:
#      old_v  new_v
# 0      1.0  15.22
# 2      2.0  15.22
# 3      3.0  15.22
# 5      4.0  15.22
# 6      5.0  15.22
# ..     ...    ...
# 494   75.0  67.50
# 496   77.0  67.50
# 497   78.0  67.50
# 498   81.0  67.50
# 499   91.0  67.50
#
# [77 rows x 2 columns]

# %%
dataALL_cut['smooth_age'] = dataALL_cut['age'].map(my_df_unique.set_index('old_v')['new_v'])
dataALL_cut
# Out:
#        No. announce_date Notified date   sex   age  smooth_age
# 2015  2016    2020-04-04      3/4/2020  หญิง  45.0   43.680000
# 2016  2017    2020-04-04      3/4/2020   ชาย  33.0   32.380000
# 2017  2018    2020-04-04      3/4/2020   ชาย  57.0   56.640000
# 2018  2019    2020-04-04      3/4/2020   ชาย  40.0   39.040000
# 2019  2020    2020-04-04      3/4/2020   ชาย  36.0   35.856009
# ...    ...           ...           ...   ...   ...         ...
# 2514  2515    2020-04-11     10/4/2020   ชาย  43.0   43.680000
# 2515  2516    2020-04-11     10/4/2020   ชาย  40.0   39.040000
# 2516  2517    2020-04-11     10/4/2020   ชาย  44.0   43.680000
# 2517  2518    2020-04-11     10/4/2020   ชาย  48.0   49.560000
# 2518  2519    2020-04-11     10/4/2020   ชาย  29.0   28.380000
#
# [500 rows x 6 columns]

# %%
plt.scatter(range(len(my_data)),my_data)

# %%
plt.scatter(range(len(my_data)),dataALL_cut['smooth_age'])

# %% [markdown]
# ## [PD] Group by

# %% [markdown]
# ### แต่ละจังหวัดมีอายุเฉลี่ยของคนที่ตรวจพบโรคเป็นกี่ปี (เรียงจากน้อยไปหามาก)

# %%
dataALL
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-01-12    99/99/9999  หญิง  61.0   ปี       China
# 1            2    2020-01-17    99/99/9999  หญิง  74.0   ปี       China
# 2            3    2020-01-22    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22    99/99/9999   ชาย  68.0   ปี       China
# 4            5    2020-01-24    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767    2021-08-12     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768    2021-08-12     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769    2021-08-12     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770    2021-08-12     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771    2021-08-12     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
dataALL.groupby('province_of_onset').mean()
# Out:
# <ipython-input-156-aaf7daec95c2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataALL.groupby('province_of_onset').mean()
#                          age        new col
# province_of_onset
#  กาญจนบุรี         29.000000  763650.000000
#  ชลบุรี            23.000000  763653.000000
#  ตราด              46.000000  763584.000000
#  นครปฐม            29.000000  763588.000000
#  สมุทรสงคราม       35.861459  763601.843750
# ...                      ...            ...
# เวียงสา            35.700109  392057.600000
# แพร่               34.868442  499237.098698
# แม่ฮ่องสอน         27.265855  330665.227642
# แล้วป่วย           43.000000  627894.000000
# ไม่ระบุ            35.696970  585795.424242
#
# [179 rows x 2 columns]

# %%
dataprovage = dataALL.groupby('province_of_onset').mean().reset_index()[['province_of_onset','age']]
dataprovage.sort_values(by=['age'])
# Out:
# <ipython-input-157-e623aa022691>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataprovage = dataALL.groupby('province_of_onset').mean().reset_index()[['province_of_onset','age']]
#     province_of_onset   age
# 60          ปทุมธานี.   5.0
# 119          สมุทสาคร  15.0
# 68          ปลายพระยา  15.0
# 50              นาวัง  19.0
# 159        อุุทัยธานี  20.0
# ..                ...   ...
# 88            ยานนาวา  57.0
# 113       สมุทรปรากรร  65.0
# 34             นคนปฐม  67.0
# 100           ลำลูกกา  67.0
# 146           อยุทธยา  70.0
#
# [179 rows x 2 columns]

# %% [markdown]
# ## [PD] Sample record

# %%
dataALL.shape
# Out:
# (835780, 12)

# %% [markdown]
# ####sampling

# %%
dataALL.sample(n=100)
# Out:
#            No. announce_date Notified date   sex        age Unit nationality  \
# 676725  676726    2021-08-05      4/8/2021   ชาย  34.000000   ปี     Burmese
# 346300  346301    2021-07-13     12/7/2021   ชาย  54.000000   ปี    Thailand
# 639205  639206    2021-08-03      2/8/2021   ชาย  31.000000   ปี    Thailand
# 799870  799871    2021-08-11     10/8/2021   ชาย  63.000000   ปี    Thailand
# 674723  674724    2021-08-05      4/8/2021   ชาย  35.700109   ปี    Thailand
# ...        ...           ...           ...   ...        ...  ...         ...
# 561342  561343    2021-07-30     29/7/2021   ชาย  21.000000   ปี    Thailand
# 516215  516216    2021-07-27     26/7/2021  หญิง  40.000000   ปี     Burmese
# 638509  638510    2021-08-03      2/8/2021  หญิง  30.000000   ปี    Thailand
# 129313  129314    2021-05-23     22/5/2021  หญิง  25.000000   ปี     Burmese
# 168719  168720    2021-06-03      2/6/2021   นาย  35.700109   ปี    Thailand
#
#        province_of_isolation  \
# ...

# %% [markdown]
# #### bootstrap sampling (สุ่มแบบใส่คืน)

# %%
dataALL.sample(n=100,replace=True)
# Out:
#            No. announce_date Notified date   sex   age Unit    nationality  \
# 379945  379946    2021-07-16     15/7/2021   ชาย  58.0   ปี       Thailand
# 329208  329209    2021-07-11     10/7/2021  หญิง  34.0   ปี  Laotian / Lao
# 385780  385781    2021-07-17     16/7/2021  หญิง  31.0   ปี       Thailand
# 560098  560099    2021-07-29     28/7/2021   นาย  17.0   ปี           ไทย?
# 319011  319012    2021-07-10      9/7/2021  หญิง  63.0   ปี       Thailand
# ...        ...           ...           ...   ...   ...  ...            ...
# 295091  295092    2021-07-07      6/7/2021  หญิง  52.0   ปี       Thailand
# 563210  563211    2021-07-30     29/7/2021   ชาย  11.0   ปี       Thailand
# 210756  210757    2021-06-18     17/6/2021  หญิง  24.0   ปี       Thailand
# 823179  823180    2021-08-12     11/8/2021  หญิง  29.0   ปี       Thailand
# 621503  621504    2021-08-02      1/8/2021  หญิง  54.0   ปี       Thailand
#
#        province_of_isolation  \
# 379945         กรุงเทพมหานคร
# ...

# %% [markdown]
# ## [PD] Save file

# %%
dataprovage.sort_values(by=['age']).to_csv('avg_age_prov.csv')

# %% [markdown]
# ## [PD] การสร้างตาราง pandas
#
# ![Unknown.jpg](data:image/jpeg;base64,...)

# %%
sales = [{'account':'Jones LLC', 'Jan':150, 'Feb':200, 'Mar':140},
         {'account':'Alpha Co', 'Jan':200, 'Feb':210, 'Mar':215},
         {'account':'Blue Inc', 'Jan':50, 'Feb':90, 'Mar':95}]
df = pd.DataFrame(sales)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %%
sales = [['Jones LLC',150,200,140],
         ['Alpha Co',200,210,215],
         ['Blue Inc',50,90,95]]
labels = ['account','Jan','Feb','Mar']
df = pd.DataFrame.from_records(sales,columns=labels)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %% [markdown]
# ## Pre-test

# %% [markdown]
#  **ตัวอย่างผู้ติดโควิดมีกี่เชื้อชาติ ?**

# %%
dataALL
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-01-12    99/99/9999  หญิง  61.0   ปี       China
# 1            2    2020-01-17    99/99/9999  หญิง  74.0   ปี       China
# 2            3    2020-01-22    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22    99/99/9999   ชาย  68.0   ปี       China
# 4            5    2020-01-24    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767    2021-08-12     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768    2021-08-12     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769    2021-08-12     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770    2021-08-12     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771    2021-08-12     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
dataALL.groupby(['nationality'])[['nationality']].count ()
# Out:
#                   nationality
# nationality
# Afghan / Afghani            4
# Afghanistan                 3
# African                     3
# Albania                     4
# Algeria                     1
# ...                       ...
# ไทย?                    84126
# ไทยใหญ่                     1
# ไทใหญ่                      1
# ไนจีเรีย                    1
# ไม่มีสัญชาติ                3
#
# [246 rows x 1 columns]

# %%
dataALL.groupby(['nationality'])[['No.']].count().\
     sort_values(by=['No.'],ascending=False)
# Out:
#                 No.
# nationality
# Thailand     648060
# ไทย?          84126
# Burmese       58803
# Burma         18707
# Cambodian     15057
# ...             ...
# Mauritians        1
# Mauritius         1
# Gambia            1
# Gambia, The       1
# Laotian           1
#
# [246 rows x 1 columns]

# %%
dataALL[['risk']]
# Out:
#                                     risk
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                  ...
# 839766                  ทัณฑสถาน/เรือนจำ
# 839767                  ทัณฑสถาน/เรือนจำ
# 839768                  ทัณฑสถาน/เรือนจำ
# 839769                  ทัณฑสถาน/เรือนจำ
# 839770                  ทัณฑสถาน/เรือนจำ
#
# [835780 rows x 1 columns]

# %% [markdown]
# **อายุเฉลี่ยของผู้ติดโควิดสัญชาติต่างๆ**

# %%
dataALL.groupby(['nationality'])[['age']].mean().sort_values(by=['age'], ascending = False)
# Out:
#                            age
# nationality
# Myanmar              77.900000
# Argentine            77.000000
# Croatia              73.000000
# Norwegian            71.666667
# Gambia               71.000000
# ...                        ...
# Kosovo               20.000000
# iranian              18.000000
# Libya                18.000000
# Azerbaijan           12.000000
# Congo (Brazzaville)   4.000000
#
# [246 rows x 1 columns]

# %%
dataALL.groupby(["nationality"])[['age']].mean().sort_values(by=['age'],ascending=False)
# Out:
#                            age
# nationality
# Myanmar              77.900000
# Argentine            77.000000
# Croatia              73.000000
# Norwegian            71.666667
# Gambia               71.000000
# ...                        ...
# Kosovo               20.000000
# iranian              18.000000
# Libya                18.000000
# Azerbaijan           12.000000
# Congo (Brazzaville)   4.000000
#
# [246 rows x 1 columns]

# %% [markdown]
# # July, 26:Practice with dataALL

# %%
dataALL_df = pd.DataFrame(dataALL)
dataALL_df

# %%
with pd.ExcelWriter('dataALL.xlsx') as writer:
    dataALL_df.to_excel(writer, sheet_name='data')

# %%
dataALL.to_excel("/content/drive/MyDrive/Year4/Data Mining")

# %%
dataALL.columns
# Out:
# Index(['No.', 'announce_date', 'Notified date', 'sex', 'age', 'Unit',
#        'nationality', 'province_of_isolation', 'risk', 'province_of_onset',
#        'district_of_onset', 'new col'],
#       dtype='object')

# %%
#select only 'announce_date' in 2020
data2020 = dataALL[(dataALL['announce_date']>= datetime(2020,1,1))&(dataALL['announce_date']<= datetime(2020,12,31))]

# %%
data2020.head()
# Out:
#   No. announce_date Notified date   sex   age Unit nationality  \
# 0   1    2020-01-12    99/99/9999  หญิง  61.0   ปี       China
# 1   2    2020-01-17    99/99/9999  หญิง  74.0   ปี       China
# 2   3    2020-01-22    99/99/9999  หญิง  73.0   ปี    Thailand
# 3   4    2020-01-22    99/99/9999   ชาย  68.0   ปี       China
# 4   5    2020-01-24    99/99/9999  หญิง  66.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset  new col
# 0               NaN        0
# 1               NaN        1
# 2             เมือง        2
# ...

# %%
data2020.tail()
# Out:
#        No. announce_date Notified date   sex        age Unit nationality  \
# 6880  6881    2020-12-31    30/12/2020  หญิง  39.000000   ปี    Thailand
# 6881  6882    2020-12-31    30/12/2020   ชาย  35.700109   ปี    Thailand
# 6882  6883    2020-12-31    30/12/2020   ชาย  54.000000   ปี    Thailand
# 6883  6884    2020-12-31    30/12/2020   ชาย  56.000000   ปี    Thailand
# 6884  6885    2020-12-31    30/12/2020   ชาย  70.000000   ปี    Thailand
#
#      province_of_isolation           risk province_of_onset district_of_onset  \
# 6880                 ระยอง  Cluster ระยอง             ระยอง             เมือง
# 6881                 ระยอง  Cluster ระยอง               NaN               NaN
# 6882                 ระยอง  Cluster ระยอง             ระยอง             เมือง
# 6883                 ระยอง  Cluster ระยอง             ระยอง             เมือง
# 6884                 ระยอง  Cluster ระยอง             ระยอง             เมือง
#
#       new col
# 6880     6880
# 6881     6881
# ...

# %%
data2020.shape
# Out:
# (6863, 12)

# %%
min(data2020['announce_date'])
# Out:
# Timestamp('2020-01-12 00:00:00')

# %%
max(data2020['announce_date'])
# Out:
# Timestamp('2020-12-31 00:00:00')

# %%
data2020['announce_date'].dt.year
# Out:
# 0       2020
# 1       2020
# 2       2020
# 3       2020
# 4       2020
#         ...
# 6880    2020
# 6881    2020
# 6882    2020
# 6883    2020
# 6884    2020
# Name: announce_date, Length: 6863, dtype: int64

# %% [markdown]
# * สรุปจำนวนผู้ป่วยตามจังหวัด เรียงจากมากไปน้อย
# * สร้างแผนภูมิวงกลม สำหรับสัดส่วนผู้ป่วยในทุกจังหวัด
# * สรุปค่าเฉลี่ยอายุของผู้ป่วยแต่ละจังหวัด
# * สรุปฐานนิยมของ Risk ในแต่ละจังหวัด

# %%
dataALL.columns
# Out:
# Index(['No.', 'announce_date', 'Notified date', 'sex', 'age', 'Unit',
#        'nationality', 'province_of_isolation', 'risk', 'province_of_onset',
#        'district_of_onset', 'new col'],
#       dtype='object')

# %%
#สรุปจำนวนผู้ป่วยตามจังหวัด เรียงจากมากไปน้อย
count_pv_onset = data2020.groupby('province_of_onset')[['No.']].count().sort_values('No.',ascending = False)
count_pv_onset
# Out:
#                     No.
# province_of_onset
# กรุงเทพมหานคร      2214
# สมุทรสาคร          1462
# ชลบุรี              659
# สมุทรปราการ         330
# ภูเก็ต              233
# ...                 ...
# สิงห์บุรี             1
# ตราด                  1
# กำแพงเพชร             1
# แพร่                  1
# อุทัยธานี             1
#
# [75 rows x 1 columns]

# %%
#สร้างแผนภูมิวงกลม สำหรับสัดส่วนผู้ป่วยในทุกจังหวัด
count_pv_onset.plot.pie(y='No.')

# %%
count_pv_onset.plot.pie(subport = )

# %%
#สรุปค่าเฉลี่ยอายุของผู้ป่วยแต่ละจังหวัด
data2020.groupby('province_of_onset')[['age']].mean().sort_values('age',ascending = False)
# Out:
#                          age
# province_of_onset
# ระนอง              57.000000
# ตราด               55.000000
# เพชรบูรณ์          51.750000
# ประจวบคีรีขันธ์    51.352941
# สิงห์บุรี          50.000000
# ...                      ...
# ชัยภูมิ            29.000000
# พังงา              24.500000
# สกลนคร             21.000000
# แม่ฮ่องสอน         21.000000
# หนองคาย            16.000000
#
# [75 rows x 1 columns]

# %%
#สรุปฐานนิยมของ Risk ในแต่ละจังหวัด
data2020.groupby('province_of_onset')[['risk']].mode().sort_values('risk',ascending = False)

# %%
import pandas as pd

# %%
data2020.groupby('province_of_onset')[['risk']].agg(pd.series.mode)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-206-64ab1693d73c> in <cell line: 1>()
# ----> 1 data2020.groupby('province_of_onset')[['risk']].agg(pd.series.mode)
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
mode_risk_pv = data2020.groupby('province_of_onset')[['risk']].apply(lambda x: x.mode())
mode_risk_pv
# Out:
#                                                                   risk
# province_of_onset
# กระบี่            0                                  Cluster สมุทรสาคร
#                   1        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# กรุงเทพมหานคร     0        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# กาญจนบุรี         0        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# กาฬสินธุ์         0                                            สนามมวย
# ...                                                                ...
# เพชรบุรี          0                                  Cluster สมุทรสาคร
# เพชรบูรณ์         0  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# เลย               0        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# แพร่              0                                            สนามมวย
# แม่ฮ่องสอน        0        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [91 rows x 1 columns]

# %%
np.unique(mode_risk_pv[['risk']],return_counts=True)
# Out:
# (array(['Cluster ระยอง', 'Cluster สมุทรสาคร', 'State Quarantine',
#         'คนต่างชาติเดินทางมาจากต่างประเทศ',
#         'คนไทยเดินทางกลับจากต่างประเทศ', 'บุคลากรด้านการแพทย์และสาธารณสุข',
#         'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ',
#         'ศูนย์กักกัน ผู้ต้องกัก', 'สถานบันเทิง', 'สนามมวย',
#         'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้',
#         'อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น'],
#        dtype=object),
#  array([ 3, 20,  4,  2,  5,  3,  1,  1,  6,  5, 36,  5]))

# %%
import collections
ct_risk_mode = collections.Counter(mode_risk_pv['risk'])
ct_risk_mode.most_common()
# Out:
# [('สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้', 36),
#  ('Cluster สมุทรสาคร', 20),
#  ('สถานบันเทิง', 6),
#  ('สนามมวย', 5),
#  ('อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น',
#   5),
#  ('คนไทยเดินทางกลับจากต่างประเทศ', 5),
#  ('State Quarantine', 4),
#  ('Cluster ระยอง', 3),
#  ('บุคลากรด้านการแพทย์และสาธารณสุข', 3),
#  ('คนต่างชาติเดินทางมาจากต่างประเทศ', 2),
#  ('ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ', 1),
#  ('ศูนย์กักกัน ผู้ต้องกัก', 1)]

# %%
ct_risk_mode_df=pd.DataFrame(ct_risk_mode.most_common(),columns=['risk','count'])
ct_risk_mode_df
# Out:
#                                                  risk  count
# 0         สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     36
# 1                                   Cluster สมุทรสาคร     20
# 2                                         สถานบันเทิง      6
# 3                                             สนามมวย      5
# 4   อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...      5
# 5                       คนไทยเดินทางกลับจากต่างประเทศ      5
# 6                                    State Quarantine      4
# 7                                       Cluster ระยอง      3
# 8                     บุคลากรด้านการแพทย์และสาธารณสุข      3
# 9                    คนต่างชาติเดินทางมาจากต่างประเทศ      2
# 10       ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ      1
# 11                             ศูนย์กักกัน ผู้ต้องกัก      1

# %%
pd.DataFrame(ct_risk_mode.most_common(),columns=['risk','count']).plot.bar(xticks=ct_risk_mode_df['risk'],['count'])
# Out:
#   File "<ipython-input-227-18120ab0ae93>", line 1
#     pd.DataFrame(ct_risk_mode.most_common(),columns=['risk','count']).plot.bar(xticks=ct_risk_mode_df['risk'],['count'])
#                                                                                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
ct_risk_mode_df.plot.bar()
plt.xticks(np.arange(0,ct_risk_mode_df.shape[0]), myRisk)
